# %% [markdown]
# # Sentiment Analysis
# 2017-2022

# %%
import pandas as pd 
import numpy as np
import re 
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from wordcloud import WordCloud, STOPWORDS 
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("2016_17 tweets.csv")
df2 = pd.read_csv("2017_18 tweets.csv")
df3 = pd.read_csv("2018_19 tweets.csv")
df4 = pd.read_csv("2019_20 tweets.csv")
df5 = pd.read_csv("2020_21 tweets.csv")
df6 = pd.read_csv("2021_22 tweets.csv")

df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)

# change string date to datetime
df["created_at"] = pd.to_datetime(df.created_at).dt.date
df.head()
# Out:
#           username replied_to_username location  verified  created_at  \
# 0          rxjjy96                                  False  2016-10-31
# 1          duvaljr                                  False  2016-10-31
# 2     prince_nueve                                  False  2016-10-31
# 3  MontezzAllen313                      Chicago     False  2016-10-31
# 4          tjvrd13                                  False  2016-10-31
#
#                                                 text
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...

# %%
df.shape
# Out:
# (11979, 6)

# %%
# clean and stem words
def preprocess_text(text): 
    # get lowercase
    text = text.lower()
    # remove numbers
#     text = re.sub(r'\d+', '', text)
    # remove quotations
    text = text.replace("\"", "")
    text = text.replace("\'", "")
    text = text.replace("&", "")
    text = text.replace(".", "")
    text = text.replace("'", "")
    # remove urls
    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text)
    # remove punctuation
    text = text.replace("_", " ")
    text = text.translate(text.maketrans('', '', string.punctuation))    
    # strip whitespace
    text = text.strip()
    # remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    words = [w for w in tokens if not w in stop_words]
    text = " ".join(w for w in words)
    # stemming
#     stemmer= PorterStemmer()
#     tokens = word_tokenize(text)
#     words = [stemmer.stem(w) for w in tokens]
#     result = " ".join(w for w in words)
    return text #result

# %%
# create a new column for processed tweets
df['processed_tweet'] = [preprocess_text(tweet) for tweet in df['text'].values]
df.head()
# Out:
#           username replied_to_username location  verified  created_at  \
# 0          rxjjy96                                  False  2016-10-31
# 1          duvaljr                                  False  2016-10-31
# 2     prince_nueve                                  False  2016-10-31
# 3  MontezzAllen313                      Chicago     False  2016-10-31
# 4          tjvrd13                                  False  2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet
# 0     russell westbrook dont get mvp season imma cry
# 1  nothing russell westbrook game changed playing...
# 2           russell westbrook damian lillard ballers
# 3                   russell westbrook win mvp season
# 4  russell westbrook mvp homecoming king presiden...

# %%
def get_polarity(tweet):
    blob = TextBlob(tweet)
    return blob.sentiment.polarity

# %%
df['polarity'] = df.processed_tweet.apply(lambda x: get_polarity(x))
df.head()
# Out:
#           username replied_to_username location  verified  created_at  \
# 0          rxjjy96                                  False  2016-10-31
# 1          duvaljr                                  False  2016-10-31
# 2     prince_nueve                                  False  2016-10-31
# 3  MontezzAllen313                      Chicago     False  2016-10-31
# 4          tjvrd13                                  False  2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet  polarity
# 0     russell westbrook dont get mvp season imma cry       0.0
# 1  nothing russell westbrook game changed playing...      -0.4
# 2           russell westbrook damian lillard ballers       0.0
# 3                   russell westbrook win mvp season       0.8
# 4  russell westbrook mvp homecoming king presiden...       0.0

# %%
# t = [1 if p >0 else 0 for p in df['polarity']]
# s = [abs(p)*100+1 for p in df['polarity']]
# plt.figure(figsize=(25, 6))
# plt.scatter('created_at', 'polarity', data=df, c = t, s = s, alpha=0.7, cmap='jet')
# plt.xticks(df['created_at'])
# plt.xlabel('Week')
# plt.ylabel('Polarity')
# plt.show()

# %% [markdown]
# ## VADER (Valence Aware Dictionary and Sentiment Reasoner)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# create object
SIA = SentimentIntensityAnalyzer()

# add col to df
df['vaderPolarity'] = df.processed_tweet.apply(lambda x: SIA.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#           username replied_to_username location  verified  created_at  \
# 0          rxjjy96                                  False  2016-10-31
# 1          duvaljr                                  False  2016-10-31
# 2     prince_nueve                                  False  2016-10-31
# 3  MontezzAllen313                      Chicago     False  2016-10-31
# 4          tjvrd13                                  False  2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet  polarity  vaderPolarity
# 0     russell westbrook dont get mvp season imma cry       0.0        -0.4767
# 1  nothing russell westbrook game changed playing...      -0.4         0.2023
# 2           russell westbrook damian lillard ballers       0.0         0.0000
# 3                   russell westbrook win mvp season       0.8         0.5859
# 4  russell westbrook mvp homecoming king presiden...       0.0         0.0000

# %% [markdown]
# # Flair pre-trained embedding-based model

# %%
from flair.models import TextClassifier
from flair.data import Sentence

# %%
flr = TextClassifier.load('en-sentiment')

def flair_prediction(x):
    sentence = Sentence(x)
    flr.predict(sentence)
    score = sentence.labels[0].score
    attitude = sentence.labels[0].value
    if attitude == "NEGATIVE":
        return -score
    else:
        return score
# Out:
# 2022-11-18 13:21:53,993 loading file /home/bdnassif/.flair/models/sentiment-en-mix-distillbert_4.pt

# %%
# %%time
#subset = df.iloc[50:75, :].copy()

# WARNING: takes about 37 minutes to run
#df['flair'] = df.processed_tweet.apply(lambda x: flair_prediction(x))
# Out:
# CPU times: user 4h 50min 3s, sys: 4min 46s, total: 4h 54min 50s
# Wall time: 36min 52s

# %%
df.head()
# Out:
#           username replied_to_username location  verified  created_at  \
# 0          rxjjy96                                  False  2016-10-31
# 1          duvaljr                                  False  2016-10-31
# 2     prince_nueve                                  False  2016-10-31
# 3  MontezzAllen313                      Chicago     False  2016-10-31
# 4          tjvrd13                                  False  2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet  polarity  vaderPolarity  \
# 0     russell westbrook dont get mvp season imma cry       0.0        -0.4767
# 1  nothing russell westbrook game changed playing...      -0.4         0.2023
# 2           russell westbrook damian lillard ballers       0.0         0.0000
# 3                   russell westbrook win mvp season       0.8         0.5859
# 4  russell westbrook mvp homecoming king presiden...       0.0         0.0000
#
#       flair
# 0 -0.989227
# 1 -0.953636
# 2  0.995221
# 3  0.999352
# 4 -0.886530

# %% [markdown]
# ## Twitter-roBERTa-base (from hugging face)
# https://huggingface.co/blog/sentiment-analysis-python

# %%
from transformers import pipeline

# %%
model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# Downloading:   0%|          | 0.00/1.52k [00:00<?, ?B/s]

# %%
# %%time

data = df.processed_tweet.tolist()

# WARNING: will take about 42 minutes to run
roberta = model(data)
# Out:
# CPU times: user 6h 40min 9s, sys: 4min 25s, total: 6h 44min 34s
# Wall time: 50min 35s

# %%
df['roberta'] = None

# get pos, neg, neu from roberta
rob_sentiment = [twt['label'] for twt in roberta]

df['roberta'] = rob_sentiment

# %%
df.head()
# Out:
#           username replied_to_username location  verified created_at  \
# 0          rxjjy96                                  False 2016-10-31
# 1          duvaljr                                  False 2016-10-31
# 2     prince_nueve                                  False 2016-10-31
# 3  MontezzAllen313                      Chicago     False 2016-10-31
# 4          tjvrd13                                  False 2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet  polarity  vaderPolarity  \
# 0     russell westbrook dont get mvp season imma cry       0.0        -0.4767
# 1  nothing russell westbrook game changed playing...      -0.4         0.2023
# 2           russell westbrook damian lillard ballers       0.0         0.0000
# 3                   russell westbrook win mvp season       0.8         0.5859
# 4  russell westbrook mvp homecoming king presiden...       0.0         0.0000
#
#       flair roberta (0, roberta)
# 0 -0.989227     NEG          NEG
# 1 -0.953636     NEG          NEG
# 2  0.995221     NEU          NEG
# 3  0.999352     POS          NEG
# 4 -0.886530     NEU          NEG

# %% [markdown]
# # Compare sentiment libraries

# %%
for _, row in df.iterrows():
    print("-------")
    print(row['text'])
    print(f"TextBlob: {row['polarity']}")
    print(f"Vader: {row['vaderPolarity']}")
    print(f"Flair: {row['flair']}")
    print(f"Roberta: {row['roberta']}")
    print("-------")
# Out:
# -------
# If Russell Westbrook don't get MVP this season imma cry
# TextBlob: 0.0
# Vader: -0.4767
# Flair: -0.9892271757125854
# Roberta: NEG
# -------
# -------
# Nothing about Russell Westbrook game changed. He has been playing this for years. Bandwagon'rs!!!
# TextBlob: -0.4
# Vader: 0.2023
# Flair: -0.9536364674568176
# Roberta: NEG
# -------
# -------
# Russell Westbrook and Damian Lillard are ballers
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9952210783958435
# Roberta: NEU
# -------
# -------
# Will Russell Westbrook win MVP this season?
# TextBlob: 0.8
# Vader: 0.5859
# Flair: 0.9993522763252258
# Roberta: POS
# -------
# -------
# Russell Westbrook for MVP, homecoming king, president, and whatever else
# TextBlob: 0.0
# Vader: 0.0
# Flair: -0.8865303993225098
# Roberta: NEU
# -------
# -------
# After a historic start of the season for Russell Westbrook, was Kevin Durant the one holding him back this whole time?
# TextBlob: 0.06666666666666667
# Vader: 0.0
# Flair: 0.9941884279251099
# Roberta: NEU
# -------
# -------
# Russell Westbrook = MVP ???
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9985159039497375
# Roberta: NEU
# -------
# -------
# RIP to the Warriors, they ain't dead Russell Westbrook just finna destroy them on Thursday
# TextBlob: -0.2
# Vader: -0.015
# Flair: -0.8888965845108032
# Roberta: NEU
# -------
# -------
# I need to design a Russell Westbrook Revenge Tour t shirt
# TextBlob: 0.0
# Vader: -0.5267
# Flair: 0.95302414894104
# Roberta: NEU
# -------
# -------
# Russell Westbrook has to be everyone's favorite player at this point.
# TextBlob: 0.5
# Vader: 0.4588
# Flair: 0.9984484910964966
# Roberta: POS
# -------
# -------
# The way Russell Westbrook been playing this season has been scary. I can't wait for OKC vs GSW.
# TextBlob: -0.5
# Vader: -0.34
# Flair: 0.9859936237335205
# Roberta: POS
# -------
# -------
# Is Russell Westbrook a million dollars on FanDuel yet?
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.8949794173240662
# Roberta: NEU
# -------
# -------
# #RussellWestbrook LeBron James, Russell Westbrook named NBA Players of the Week
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9559224843978882
# Roberta: NEU
# -------
# -------
# Russell Westbrook is my spirit animal
# TextBlob: 0.0
# Vader: 0.1779
# Flair: 0.9951849579811096
# Roberta: NEU
# -------
# -------
# This nigga Russell Westbrook really be putting up MyPlayer numbers.
# TextBlob: 0.2
# Vader: 0.0
# Flair: 0.9973533153533936
# Roberta: NEU
# -------
# -------
# Russell Westbrook for MVP ?
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9985159039497375
# Roberta: NEU
# -------
# -------
# Russell Westbrook is gonna average a triple double this season.
# TextBlob: -0.075
# Vader: 0.0
# Flair: 0.9984049201011658
# Roberta: NEU
# -------
# -------
# Russell Westbrook is gonna go in hard against the Warriors on Thursday. Can't wait!
# TextBlob: -0.2916666666666667
# Vader: -0.1027
# Flair: 0.9893062710762024
# Roberta: POS
# -------
# -------
# I can't wait to see Thunder vs Warriors
# Russell Westbrook putting up a quadruple double
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9182839393615723
# Roberta: POS
# -------
# -------
# Coming up at 6 on @kfor, #Thunder's Russell Westbrook on Steven Adams, contract ext. in line for 3 OKC players, and #Sooners and #OKState FB
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9947563409805298
# Roberta: NEU
# -------
# -------
# I honestly believe that Russell Westbrook will go down as the greatest point guard that has and will ever live.
# TextBlob: 0.5787878787878787
# Vader: 0.802
# Flair: 0.997795820236206
# Roberta: POS
# -------
# -------
# I hope Russell Westbrook shits all over the Warriors
# TextBlob: 0.0
# Vader: -0.0516
# Flair: -0.8553363084793091
# Roberta: NEG
# -------
# -------
# Russell Westbrook is gonna be that Kobe when shaq left the team (Kevin Durant)
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.6450451016426086
# Roberta: NEU
# -------
# -------
# Russell Westbrook is the first player to record two triple-doubles in the first  three games of the season since Magic Johnson in 1982-83.
# TextBlob: 0.3333333333333333
# Vader: 0.0
# Flair: 0.904444694519043
# Roberta: POS
# -------
# -------
# Russell Westbrook averaging 39/12/12 through 3 games. That any good?
# TextBlob: 0.7
# Vader: 0.4404
# Flair: 0.9923503994941711
# Roberta: POS
# -------
# -------
# LeBron James and Russell Westbrook were named NBA Players of the Week.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9581050276756287
# Roberta: NEU
# -------
# -------
# Mon deck semaine 2 : B. Griffin, S. Curry, R. Westbrook, I. Thomas, B. Bogdanovic, K. Love, D. Russell #TTFL
# TextBlob: 0.5
# Vader: 0.6369
# Flair: 0.9967080354690552
# Roberta: NEU
# -------
# -------
# Russell Westbrook and Anthony Davis are starting off the season OTHER WORLDLY. If OKC makes the playoffs Westbrook has GOT to win MVP
# TextBlob: 0.4
# Vader: 0.5859
# Flair: 0.9954054355621338
# Roberta: NEU
# -------
# -------
# Russell Westbrook is my spirit animal
# TextBlob: 0.0
# Vader: 0.1779
# Flair: 0.9951849579811096
# Roberta: NEU
# -------
# -------
# Russell Westbrook named Western Conference Player of the Week
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9830936193466187
# Roberta: NEU
# -------
# -------
# Russell Westbrook is like playing NBA Live '06 with a 99 rated Kobe Bryant on rookie with all the game sliders up.
# TextBlob: -0.1318181818181818
# Vader: 0.5106
# Flair: -0.8804433345794678
# Roberta: NEU
# -------
# -------
# Russell Westbrook or Russell Bestbrook?
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9977267384529114
# Roberta: NEU
# -------
# -------
# ESPN is out here talking about if Russell Westbrook is going to average a Triple/Dub this season after 3 fucking games.
# TextBlob: -0.375
# Vader: 0.0
# Flair: -0.9937471151351929
# Roberta: NEG
# -------
# -------
# Russell Westbrook wins mvp this year. heard it here first
# TextBlob: 0.275
# Vader: 0.5719
# Flair: 0.9784960150718689
# Roberta: POS
# -------
# -------
# Russell Westbrook is like that guy that walks round wit the drum guitar harmonica piano etc all on him. #1manband
# TextBlob: -0.2
# Vader: 0.4767
# Flair: -0.8548935651779175
# Roberta: NEU
# -------
# -------
# Kornheiser: "Russell Westbrook is fueled by the hatred of a thousand suns at Kevin Durant." For sure. LOL. #PTI
# TextBlob: 0.65
# Vader: -0.0258
# Flair: -0.9000057578086853
# Roberta: NEG
# -------
# -------
# Russell Westbrook
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9933392405509949
# Roberta: NEU
# -------
# -------
# Hope the players of OKC not named Russell Westbrook realize they won't get to take a single shot on Thursday. Russ gunna do the most
# TextBlob: -0.07142857142857142
# Vader: 0.4404
# Flair: -0.9837539792060852
# Roberta: NEU
# -------
# -------
# Russell Westbrook really gonna average a triple double this season lol
# TextBlob: 0.2125
# Vader: 0.4215
# Flair: 0.9949703812599182
# Roberta: NEU
# -------
# -------
# Tom Brady = LeBron
# Derek Carr = Russell Westbrook
#
# 😈😈😈😈
# TextBlob: 0.0
# Vader: 0.9001
# Flair: 0.9978592991828918
# Roberta: NEU
# -------
# -------
# Russell Westbrook led the Thunder to a 3-0 week behind a league-leading 38.7 points and 11.7 assists to go with 12.3 rebounds per game…
# TextBlob: -0.4
# Vader: 0.0
# Flair: 0.9969401359558105
# Roberta: NEU
# -------
# -------
# Russell Westbrook led the Thunder to a 3-0 week behind a league-leading 38.7 points and 11.7 assists to go with 12.3 rebounds per game…
# TextBlob: -0.4
# Vader: 0.0
# Flair: 0.9969401359558105
# Roberta: NEU
# -------
# -------
# The Thunder don't play today. Russell Westbrook still might put up a triple-double.
# TextBlob: 0.0
# Vader: -0.2584
# Flair: -0.7460153102874756
# Roberta: NEU
# -------
# -------
# Russell Westbrook has officially reached legendary status
# TextBlob: 1.0
# Vader: 0.1027
# Flair: 0.9993104934692383
# Roberta: POS
# -------
# -------
# West POW Russell Westbrook is first player with at least 100 points, 30 rebounds &amp; 30 assists in team's first 3 games. #NBA #okcthunder
# TextBlob: 0.06666666666666667
# Vader: 0.0
# Flair: -0.7314565777778625
# Roberta: NEU
# -------
# -------
# Russell Westbrook
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9933392405509949
# Roberta: NEU
# -------
# -------
# Charles Barkley better put Russell Westbrook in his top 5 if he averages a triple double this year, since that goes by his top 5 logic.
# TextBlob: 0.375
# Vader: 0.6705
# Flair: -0.9957116842269897
# Roberta: NEU
# -------
# -------
# Hey @bomani_jones, my 9 yr old is going as Russell Westbrook. I just got back in my car &amp; heard the end of that segment. Can you reiterate?
# TextBlob: 0.05
# Vader: 0.0
# Flair: -0.63307785987854
# Roberta: NEU
# -------
# -------
# Y'all think Russell Westbrook going to average a triple double when the season over? 🤔
# TextBlob: -0.075
# Vader: 0.0
# Flair: -0.9598849415779114
# Roberta: NEU
# -------
# -------
# Everybody a Russell Westbrook fan now but probably don't know where he went to college... Stop bangwangin 😂😭😂😭😂
# TextBlob: 0.0
# Vader: 0.3818
# Flair: -0.7190865874290466
# Roberta: NEG
# -------
# -------
# team with michael jordan, Russell westbrook, homer, Anthony davis, and eminem
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.7941648960113525
# Roberta: NEU
# -------
# -------
# #Thunder SG-PG Victor Oladipo said superstar PG-SG Russell Westbrook will do anything to win.
# TextBlob: 0.8
# Vader: 0.5859
# Flair: 0.5553225874900818
# Roberta: NEU
# -------
# -------
# #stats #Thunder superstar PG-SG Russell Westbrook is the first player with a 50 point-triple double since Kareem Abdul-Jabbar in 1975.
# TextBlob: 0.125
# Vader: 0.0
# Flair: 0.9992851614952087
# Roberta: NEU
# -------
# -------
# #stats #Thunder superstar PG Russell Westbrook triple-doubled Friday, had 13 reb, 10 ast, 2 stl, 15-20 FT, 5 TOs, 17-44 FG (2 3s), 51 points
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9693596959114075
# Roberta: NEU
# -------
# -------
# Russell Westbrook sneaker commercial is so LIT bruh !
# TextBlob: 0.0
# Vader: 0.0
# Flair: -0.9974132180213928
# Roberta: NEU
# -------
# -------
# Focus level on Russell Westbrook.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9986592531204224
# Roberta: NEU
# -------
# -------
# GQ did an awesome profile on Russell Westbrook for their November issue. Read it.
# TextBlob: 1.0
# Vader: 0.6249
# Flair: 0.9424121975898743
# Roberta: POS
# -------
# -------
# The Cavaliers’ LeBron James and the Thunder’s Russell Westbrook are the NBA Players of the Week
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.8612021207809448
# Roberta: NEU
# -------
# -------
# I like how its goin with Russell Westbrook. 100 30 and 30 in 3 games.. 👌
# TextBlob: 0.0
# Vader: 0.824
# Flair: 0.9363688230514526
# Roberta: NEU
# -------
# -------
# Russell Westbrook for MVP #earlypredictions 🤔
# TextBlob: 0.0
# Vader: 0.0
# Flair: -0.5221704840660095
# Roberta: NEU
# -------
# -------
# #hoopshype #nba Russell Westbrook 'wreaking havoc' on the NBA
# TextBlob: 0.0
# Vader: -0.5994
# Flair: -0.9903823733329773
# Roberta: NEG
# -------
# -------
# Russell Westbrook's real life putting up a triple double every night somehow😂
# TextBlob: 0.1
# Vader: 0.4404
# Flair: 0.8729110360145569
# Roberta: NEU
# -------
# -------
# #AndreDrummond LeBron James, Russell Westbrook named NBA Players of the Week
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9315798282623291
# Roberta: NEU
# -------
# -------
# How could you not like Russell Westbrook
# TextBlob: 0.0
# Vader: 0.3612
# Flair: -0.5917288064956665
# Roberta: NEU
# -------
# -------
# My MyPlayer damn near is Russell Westbrook except I'm not dropping Triple doubles like he is.
# TextBlob: 0.1
# Vader: -0.0516
# Flair: 0.9159789085388184
# Roberta: NEU
# -------
# -------
# Russell Westbrook gone make a statement Thursday it's on thunder vs warriors
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.7243372201919556
# Roberta: NEU
# -------
# -------
# #KiaWhoYaGot #sweepstakes  Russell Westbrook
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9942463040351868
# Roberta: NEU
# -------
# -------
# Y'all stop sucking off Russell Westbrook, you should be scoring 50 a game when you shooting 40+ times
# TextBlob: -0.4
# Vader: -0.296
# Flair: 0.9914885759353638
# Roberta: NEG
# -------
# -------
# Russell Westbrook the best PG in the league
# TextBlob: 1.0
# Vader: 0.6369
# Flair: 0.9995705485343933
# Roberta: POS
# -------
# -------
# Russell Westbrook for MVP
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9985159039497375
# Roberta: NEU
# -------
# -------
# Russell Westbrook new commercial 🐐 ... talk about it ... he putting up numbers and OKC 3-0. Talk about it
# TextBlob: 0.06818181818181818
# Vader: 0.0
# Flair: -0.9981086254119873
# Roberta: NEU
# -------
# -------
# How many triple doubles will Russell Westbrook finish with this season? @ESPNNBA @NBAonTNT @NBA
# TextBlob: 0.5
# Vader: 0.0
# Flair: 0.99798583984375
# Roberta: NEU
# -------
# -------
# russell westbrook really gonna average a triple double and yall gonna be big mad.
# TextBlob: -0.115
# Vader: -0.4939
# Flair: 0.9598158597946167
# Roberta: NEU
# -------
# -------
# RUSSELL WESTBROOK
# RUSSELL WESTBROOK
# RUSSELL WESTBROOK
# RUSSELL WESTBROOK
# #ThunderUp  🔥🔥🔥🔥🔥😭🔥🔥🔥🔥
# TextBlob: 0.0
# Vader: -0.967
# Flair: 0.994706928730011
# Roberta: NEU
# -------
# -------
# Wassup people. @TropicalBlanket here tonight.
#
# I'm afraid of Russell Westbrook
# TextBlob: -0.6
# Vader: 0.0
# Flair: -0.999679684638977
# Roberta: NEU
# -------
# -------
# The way Russell Westbrook dunks is the same way I approach my life.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9998281002044678
# Roberta: NEU
# -------
# -------
# I really enjoy watching Russell Westbrook play
# TextBlob: 0.4
# Vader: 0.7089
# Flair: 0.9923948049545288
# Roberta: POS
# -------
# -------
# You had to know them snakes weren't gonna catch Russell Westbrook. All he needs is a crease.
# TextBlob: 0.0
# Vader: 0.0
# Flair: -0.8431987762451172
# Roberta: NEG
# -------
# -------
# Inspire your space with this iconic image of basketball player, Russell Westbrook, of the Oklahoma City Thunder. Sleek in design and deta...
# TextBlob: 0.5
# Vader: 0.5719
# Flair: 0.9972167015075684
# Roberta: NEU
# -------
# -------
# Miami gonna beat okc Richardson with the clamps on westbrick
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.999625563621521
# Roberta: NEU
# -------
# -------
# The way Russell Westbrook dunks is the same way I approach my life.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9998281002044678
# Roberta: NEU
# -------
# -------
# Russell Westbrook is the guy to watch if you trying to get right before a game. 🔒💯
# TextBlob: -0.05714285714285716
# Vader: 0.0
# Flair: -0.9382938742637634
# Roberta: NEU
# -------
# -------
# I get to watch my @MiamiHEAT and be entertained by Russell Westbrook in the same game tonight! Exactly why I bought #NBALeaguePass !!
# TextBlob: -0.07500000000000001
# Vader: 0.4019
# Flair: 0.9947350025177002
# Roberta: NEU
# -------
# -------
# Just realized I said Russell Wilson plays for the thunder... During a presentation... I meant Russell Westbrook. I'm going into hibernation
# TextBlob: 0.0
# Vader: 0.25
# Flair: 0.8757648468017578
# Roberta: NEU
# -------
# -------
# Russell = Curry, Ingram = Durant Randle = Green, Clarkson = Westbrook, Young = Kobe, Williams = Iverson, Nance = Griffin #Lakers 😂😂😂🙌🏽🙏🏽🙌🏽💪🏽
# TextBlob: -0.05
# Vader: 0.8271
# Flair: 0.9733773469924927
# Roberta: NEU
# -------
# -------
# Westbrook could win MVP, but Russell's OKC will never beat GSW. Forget that
# TextBlob: 0.8
# Vader: 0.6669
# Flair: 0.9937894940376282
# Roberta: POS
# -------
# -------
# Russell Westbrook for MVP...fave this
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9988381266593933
# Roberta: NEU
# -------
# -------
# team with Mario, ross teeter, jerry lucas, Caleb Barnes, and Russell westbrook
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9908322691917419
# Roberta: NEU
# -------
# -------
# Russell Westbrook ain't even 28 yet and already the greatest basketball player since Kobe.
# TextBlob: 1.0
# Vader: 0.6369
# Flair: 0.9211772084236145
# Roberta: POS
# -------
# -------
# I wonder do that man Russell Westbrook get tired 🤔🤔
# TextBlob: -0.4
# Vader: -0.4404
# Flair: -0.9998676776885986
# Roberta: NEU
# -------
# -------
# The Oklahoma City Thunder lead the league in field goal attempts per game, and nearly 30% of them come from Russell Westbrook.
# TextBlob: -0.15
# Vader: 0.0
# Flair: 0.9963879585266113
# Roberta: NEU
# -------
# -------
# The way Russell Westbrook dunks is the same way I approach my life.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9998281002044678
# Roberta: NEU
# -------
# -------
# UPDATED: TOP 10 @idfsdaily
#
# Anthony Davis
# Russell Westbrook
# James Harden
# Kevin Durant
# CP3
# John Wall
# Stephen Curry
# Kemba
# Draymond
# Drummond
# TextBlob: 0.5
# Vader: 0.2023
# Flair: 0.9880680441856384
# Roberta: NEU
# -------
# -------
# The Russell westbrook commercial with the uzi song go crazy! 😂
# TextBlob: -0.3
# Vader: 0.128
# Flair: -0.9730556011199951
# Roberta: NEU
# -------
# -------
# "I do what I want" "Chill you're not Russell Westbrook"
# TextBlob: 0.0
# Vader: 0.0772
# Flair: 0.7892865538597107
# Roberta: NEU
# -------
# -------
# 5 NBA players you don't want smoke with: Matt Barnes, Melo, Russell Westbrook, John Wall, Demarcus Cousins
# TextBlob: 0.0
# Vader: -0.0572
# Flair: 0.9887588024139404
# Roberta: NEU
# -------
# -------
# The way Russell Westbrook dunks is the same way I approach my life.
# TextBlob: 0.0
# Vader: 0.0
# Flair: 0.9998281002044678
# Roberta: NEU
# -------
# -------
# What would Russell Westbrook do is my new life motto
# TextBlob: 0.1363636363636364
# Vader: 0.0
# Flair: 0.9611347317695618
# Roberta: NEU
# -------
# -------
# team with Russell westbrook, derrick rose, jerry lucas, Deandre jordan, and spongebob
# TextBlob: 0.6
# Vader: 0.0
# Flair: 0.9934549927711487
# Roberta: NEU
# -------
# -------
# Question of the week: do you hate Kevin Durant more than you love Russell Westbrook?
# TextBlob: -0.15
# Vader: 0.128
# Flair: -0.9925355911254883
# Roberta: NEG
# -------

# %% [markdown]
# ## Export Data to Excel for Graphing in PowerPoint

# %%
exportName = "sentiment_analysis.xlsx"

#df.to_excel(exportName, index=False)

# %%
import pandas as pd
df = pd.read_excel("sentiment_analysis.xlsx")

# %%
df.head()
# Out:
#           username replied_to_username location  verified created_at  \
# 0          rxjjy96                                  False 2016-10-31
# 1          duvaljr                                  False 2016-10-31
# 2     prince_nueve                                  False 2016-10-31
# 3  MontezzAllen313                      Chicago     False 2016-10-31
# 4          tjvrd13                                  False 2016-10-31
#
#                                                 text  \
# 0  If Russell Westbrook don't get MVP this season...
# 1  Nothing about Russell Westbrook game changed. ...
# 2   Russell Westbrook and Damian Lillard are ballers
# 3        Will Russell Westbrook win MVP this season?
# 4  Russell Westbrook for MVP, homecoming king, pr...
#
#                                      processed_tweet  polarity  vaderPolarity  \
# 0     russell westbrook dont get mvp season imma cry       0.0        -0.4767
# 1  nothing russell westbrook game changed playing...      -0.4         0.2023
# 2           russell westbrook damian lillard ballers       0.0         0.0000
# 3                   russell westbrook win mvp season       0.8         0.5859
# 4  russell westbrook mvp homecoming king presiden...       0.0         0.0000
#
#       flair roberta
# 0 -0.989227     NEG
# 1 -0.953636     NEG
# 2  0.995221     NEU
# 3  0.999352     POS
# 4 -0.886530     NEU
